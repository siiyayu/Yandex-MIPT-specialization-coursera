# %% [markdown]
# # Задача 2

# %%
# Out:
# 3

# %%
import scipy.linalg
import matplotlib.pyplot as plt
import numpy as np

# %%
f = lambda x: np.sin(x / 5) * np.exp(x / 10) + 5 * np.exp(-x / 2)

# %% [markdown]
# A - матрица x^n полинома, x - коэффициенты, b -  свободные члены

# %%
#Нарисуем график функции:
x = np.arange(1, 15, 0.1)
plt.plot(x, f(x))
plt.ylabel('$f(x)$')
plt.xlabel('$x$')
plt.show()

# %% [markdown]
# [1]. Сформируйте систему линейных уравнений (то есть задайте матрицу коэффициентов A и свободный вектор b) для многочлена первой степени, который должен совпадать с функцией f в точках 1 и 15. Решите данную систему с помощью функции scipy.linalg.solve. Нарисуйте функцию f и полученный многочлен. Хорошо ли он приближает исходную функцию?

# %%
p = 1 # порядок полинома
A1 = [[1 ** n for n in range(p + 1)], [15 ** n for n in range(p + 1)]]
b1 = [f(1), f(15)]
k1 = scipy.linalg.solve(A1, b1)
k1
# Out:
# array([ 3.43914511, -0.18692825])

# %%
g1 = lambda x, k: k[0] + k[1]*x
plt.plot(x, f(x))
plt.plot(x, g(x, k1))
plt.xlabel('$x$')
plt.ylabel('$f(x), g(x)$')
plt.show()

# %%
p = 2
A2 = [[1 ** n for n in range(p + 1)],
      [8 ** n for n in range(p + 1)],
      [15 ** n for n in range(p + 1)]]
b2 = [f(1), f(8), f(15)]
k2 = scipy.linalg.solve(A2, b2)
k
# Out:
# array([ 3.32512949, -0.06531159, -0.00760104])

# %%
g2 = lambda x, k: k[0] + k[1]*x + k[2]*x**2
plt.plot(x, f(x))
plt.plot(x, g2(x, k2))
plt.xlabel('$x$')
plt.ylabel('$f(x), g2(x)$')
plt.show()

# %%
p = 3
A3 = [[1 ** n for n in range(p + 1)],
      [4 ** n for n in range(p + 1)],
      [10 ** n for n in range(p + 1)],
      [15 ** n for n in range(p + 1)]]
b3 = [f(1), f(4), f(10), f(15)]
k3 = scipy.linalg.solve(A3, b3)
k3
# Out:
# array([ 4.36264154, -1.29552587,  0.19333685, -0.00823565])

# %%
g3 = lambda x, k: k[0] + k[1] * x + k[2] * x ** 2 + k[3] * x ** 3 
plt.plot(x, f(x))
plt.plot(x, g3(x, k3))
plt.xlabel('$x$')
plt.ylabel('$f(x), g3(x)$')
plt.show()
