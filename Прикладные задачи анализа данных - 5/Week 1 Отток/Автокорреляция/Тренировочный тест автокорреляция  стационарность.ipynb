# %%
import pandas as pd
import numpy as np

# %%
milk = pd.read_csv('monthly-milk-production.csv',';', index_col=['month'], parse_dates=['month'], dayfirst=True)
milk.head()
# Out:
#             milk
# month
# 1962-01-01   589
# 1962-02-01   561
# 1962-03-01   640
# 1962-04-01   656
# 1962-05-01   727

# %%
milk.plot()

# %%
import statsmodels.api as sm
sm.tsa.stattools.adfuller(milk['milk'])[1]
# Out:
# 0.6274267086030337

# %%
milk.index.days_in_month.shape
# Out:
# (168,)

# %%
# milk.milk = np.divide(milk.milk, milk.index.days_in_month)
milk.milk = milk.milk/milk.index.days_in_month
milk.head()
# Out:
#                  milk
# month
# 1962-01-01  19.000000
# 1962-02-01  20.035714
# 1962-03-01  20.645161
# 1962-04-01  21.866667
# 1962-05-01  23.451613

# %%
milk.plot()

# %%
round(sum(milk.milk), 2)
# Out:
# 4166.33
